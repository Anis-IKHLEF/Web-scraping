# %%
import requests
url="https://dz.kompass.com/r/wilaya-bejaia/dz_dz06/"
headers = { "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36 Edg/144.0.0.0"}
data=requests.get(url, headers=headers)
print(data.status_code)
# Out:
# 403

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

headers = {
    "Authorization": "Bearer 50805888-fcb9-493b-bc74-83be83ff10a1",
    "Content-Type": "application/json"
}

web = "https://dz.kompass.com"
url = "https://dz.kompass.com/r/wilaya-bejaia/dz_dz06/"
deslike = []
page_number = 1

while url:
    
    data = {
        "zone": "web_unlocker1",
        "url": url,
        "format": "raw"
    }
    response = requests.post(
        "https://api.brightdata.com/request",
        json=data,
        headers=headers
    )
    
    soup = BeautifulSoup(response.text, "html.parser")
    
    
    jobs = soup.select("div.prod_list")
    for n, job in enumerate(jobs, start=1 + len(deslike)):
        entreprise = job.select_one("span.titleSpan")
        ville = job.select_one("span.placeText")
        phone = job.select_one("input[id^=freePhone--]")  # input dont l'id commence par freePhone--
        
        deslike.append({
            "entreprise": entreprise.get_text(strip=True) if entreprise else "",
            "ville": ville.get_text(strip=True) if ville else "",
            "telephone": phone.get("value") if phone else "",
            "Number": n
        })
    
    
    next_button = soup.select_one("li.searchItemLi > a[href*='page-']")
    if next_button:
        current_url = web + next_button.get("href")
        page_number += 1
        time.sleep(1)  
    else:
        url = None  

print(deslike)
df = pd.DataFrame(deslike)
df.to_excel("Entreprises_Bejaia.xlsx", index=False)
print("Fichier Excel créé : Entreprises_Bejaia.xlsx")
# Out:
# [{'entreprise': '', 'ville': '', 'telephone': '', 'Number': 1}, {'entreprise': 'Etablissement de Commerce International,Sarl, ECI BOUDIAB', 'ville': 'Béjaia - Algérie', 'telephone': '+213 661 63 06 26', 'Number': 2}, {'entreprise': 'Complexe Agroalimentaire EL KSEUR,Sarl, CAA', 'ville': 'El kseur - Algérie', 'telephone': '+213 561 60 20 91', 'Number': 3}, {'entreprise': "MPS DE L'EST,EURL", 'ville': 'El kseur - Algérie', 'telephone': '+213 561 69 84 50', 'Number': 4}, {'entreprise': 'TMAC,Eurl', 'ville': 'Akbou - Algérie', 'telephone': '+213 560 91 35 58', 'Number': 5}, {'entreprise': 'Béjaia Equipements Industriels,Sarl, BEI', 'ville': 'Béjaia - Algérie', 'telephone': '+213 34 16 81 90', 'Number': 6}, {'entreprise': 'ETS WEB World Emballage', 'ville': 'Oued ghir - Algérie', 'telephone': '+213 779 89 23 49', 'Number': 7}, {'entreprise': "Société d'Importation de l'Est Algérien,Sarl, SIESTAL", 'ville': 'Béjaia - Algérie', 'telephone': '+213 982 40 09 91', 'Number': 8}, {'entreprise': 
# ...
